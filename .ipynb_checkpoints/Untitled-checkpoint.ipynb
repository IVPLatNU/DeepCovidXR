# %%
# Examples of GradCAM visualization
import numpy as np
import os
from tensorflow.keras.preprocessing import image
import argparse
import matplotlib.pyplot as plt
from matplotlib import cm
from vis.visualization import  overlay
from utils import imgUtils, trainFeatures
# Out:
# Using TensorFlow backend.

# %%
if __name__=='__main__':
# =============================================================================
#     args = get_args()
#     weights = args.weight_path[0]
# =============================================================================
    weights = 'D:\covid\Ensemble\covid_weights'
    img_size = 224
    dropout = 0.3
    crop_stat = 'uncrop'
        
    features = trainFeatures()
    img_proc = imgUtils(img_size)
    
    current_path = os.getcwd()
    img_name = 'pos_sample1.jpg'
    img_path = os.path.join(current_path, 'sample_images', img_name)
    original_image = image.load_img(img_path, target_size = (img_size, img_size), 
                                    color_mode='rgb', interpolation = 'lanczos')
    img_array = np.asarray(original_image, dtype='float64')
    img_preproc = img_proc.preprocess(img_array)
    img = np.expand_dims(img_preproc, axis=0)

    res_224, xception_224, dense_224, inception_224, inceptionres_224, efficient_224 = features.getAllModel(img_size, weights, crop_stat)
    models = [res_224, xception_224, dense_224, inception_224, inceptionres_224, efficient_224]
    
    # Save overlay heatmap
    visualization1 = img_proc.gradCAM(img, img_preproc, models)

# %%
visualization1.shape
# Out:
# (224, 224, 3)

# %%
# %matplotlib inline
plt.rcParams['figure.figsize'] = (18, 6)

# Matplotlib preparations
fig, axes = plt.subplots(1, 3)

axes[0].imshow(img_array[..., 0], cmap='gray') 
axes[0].set_title('Input')
axes[1].imshow(visualization1)
axes[1].set_title('Grad-CAM')
heatmap = np.uint8((cm.jet(visualization1))[..., :3]*255)
original = np.uint8(cm.gray(img_array[..., 0])[..., :3]*255)
axes[2].imshow(overlay(heatmap, original))
axes[2].set_title('Overlay')
plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-4-09281921a99b> in <module>
#      11 heatmap = np.uint8((cm.jet(visualization1))[..., :3]*255)
#      12 original = np.uint8(cm.gray(img_array[..., 0])[..., :3]*255)
# ---> 13 axes[2].imshow(overlay(heatmap, original))
#      14 axes[2].set_title('Overlay')
#      15 plt.show()
#
# ~\Anaconda3\envs\tf-gpu\lib\site-packages\vis\visualization\__init__.py in overlay(array1, array2, alpha)
#      46         raise ValueError("`alpha` needs to be between [0, 1]")
#      47     if array1.shape != array2.shape:
# ---> 48         raise ValueError('`array1` and `array2` must have the same shapes')
#      49
#      50     return (array1 * alpha + array2 * (1. - alpha)).astype(array1.dtype)
#
# ...

# %%
import keras

# %%
from vis.utils import utils
from vis.visualization import visualize_cam, overlay

# %%
visualization3 = visualize_cam(res_224, 
                              layer_idx= utils.find_layer_idx(res_224, 'last'), 
                              filter_indices=0, 
                              seed_input=img_preproc, 
                              penultimate_layer_idx = utils.find_layer_idx(res_224, 'conv5_block3_3_bn'), 
                             backprop_modifier=None)

# %%
visualization3.shape
# Out:
# (224, 224, 3)

# %%
plt.imshow(visualization3)

# %%
visualization2 = visualize_cam(dense_224, 
                              layer_idx= utils.find_layer_idx(dense_224, 'last'), 
                              filter_indices=0, 
                              seed_input=img_preproc, 
                              penultimate_layer_idx = utils.find_layer_idx(dense_224, 'bn'), 
                             backprop_modifier=None)

# %%
plt.imshow(visualization2)

# %%
visualization_avg = np.mean([visualization2, visualization3], axis = 0)

# %%
visualization_avg.shape
# Out:
# (224, 224, 3)

# %%
visualization2
# Out:
# array([[[  0,   0, 255],
#         [  0,   0, 255],
#         [  0,   0, 255],
#         ...,
#         [  0,   0, 255],
#         [  0,   0, 255],
#         [  0,   0, 254]],
#
#        [[  0,   0, 255],
#         [  0,   0, 255],
#         [  0,   0, 255],
#         ...,
#         [  0,   0, 250],
#         [  0,   0, 250],
#         [  0,   0, 245]],
#
#        [[  0,   0, 255],
#         [  0,   0, 255],
#         [  0,   0, 254],
#         ...,
#         [  0,   0, 241],
#         [  0,   0, 241],
#         [  0,   0, 241]],
#
#        ...,
#
#        [[  0,   0, 127],
#         [  0,   0, 127],
#         [  0,   0, 127],
#         ...,
#         [ 70, 255, 176],
#         [ 73, 255, 173],
#         [ 76, 255, 170]],
#
#        [[  0,   0, 127],
#         [  0,   0, 127],
#         [  0,   0, 127],
#         ...,
#         [ 76, 255, 170],
#         [ 79, 255, 166],
#         [ 79, 255, 166]],
#
#        [[  0,   0, 127],
#         [  0,   0, 127],
#         [  0,   0, 127],
# ...

# %%
visualization_avg
# Out:
# array([[[  0. ,   0. , 227.5],
#         [  0. ,   0. , 225. ],
#         [  0. ,   0. , 223. ],
#         ...,
#         [  0. ,   0. , 191. ],
#         [  0. ,   0. , 191. ],
#         [  0. ,   0. , 190.5]],
#
#        [[  0. ,   0. , 225. ],
#         [  0. ,   0. , 223. ],
#         [  0. ,   0. , 220.5],
#         ...,
#         [  0. ,   0. , 188.5],
#         [  0. ,   0. , 188.5],
#         [  0. ,   0. , 186. ]],
#
#        [[  0. ,   0. , 223. ],
#         [  0. ,   0. , 220.5],
#         [  0. ,   0. , 218. ],
#         ...,
#         [  0. ,   0. , 184. ],
#         [  0. ,   0. , 184. ],
#         [  0. ,   0. , 184. ]],
#
#        ...,
#
#        [[  0. ,   0. , 127. ],
#         [  0. ,   0. , 127. ],
#         [  0. ,   0. , 127. ],
#         ...,
#         [ 35. , 127.5, 151.5],
#         [ 36.5, 127.5, 150. ],
#         [ 38. , 127.5, 148.5]],
#
#        [[  0. ,   0. , 127. ],
#         [  0. ,   0. , 127. ],
#         [  0. ,   0. , 127. ],
#         ...,
# ...

# %%
plt.imshow(np.uint8(visualization_avg))

# %%
heatmap = np.uint8(plt.jet(visualization_avg)[:,:,:,0]*255)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-165-5cbf8bfe6b95> in <module>
# ----> 1 heatmap = np.uint8(plt.jet(visualization_avg)[:,:,:,0]*255)
#
# TypeError: jet() takes 0 positional arguments but 1 was given

# %%
heatmap.shape
# Out:
# (224, 224, 3)

# %%
heatmap.shape
# Out:
# (224, 224, 3)

# %%
plt.imshow(heatmap)

# %%
combined = overlay(heatmap, original)

# %%
plt.imshow(combined)

# %%
visualization4 = visualize_cam(inception_224, 
                              layer_idx= utils.find_layer_idx(inception_224, 'last'), 
                              filter_indices=0, 
                              seed_input=img_preproc, 
                              penultimate_layer_idx = utils.find_layer_idx(inception_224, 'mixed10'), 
                             backprop_modifier=None)

# %%
visualization_avg = np.mean([visualization2, visualization3, visualization4], axis = 0)

# %%
plt.imshow(visualization_avg)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
heatmap = np.uint8(cm.jet(visualization_avg[...,0])*255)

# %%
heatmap.shape
# Out:
# (224, 224, 4)

# %%
heatmap = heatmap[...,:3]

# %%
plt.imshow(heatmap)
